# %%
import numpy as np
import qinfer as qi
import qutip as qu
import matplotlib.pyplot as plt
from custom_models import simple_precession_with_noise
from optimization import *
import joblib

# %%
from generate_experiments import run_case, run_case_n_times, MSE
from datetime import datetime

rng = np.random.default_rng(seed=1)

number_of_cases = 1
number_of_shots = 200
n_repeat = 10

true_values_list = [np.array([[0, rng.uniform(0, 0.5, size=1)[0]]]) for _ in range(number_of_cases)]

# %%
true_values_list
# Out:
# [array([[0.        , 0.25591081]])]

# %%
date = datetime.today().strftime('%Y-%m-%d_%H.%M')


filenames = [date+"_"+ "case_"+str(i)+".job" for i in range(number_of_cases)]
result_dictionary = [run_case_n_times(true_values_i, number_of_shots, n_repeat=n_repeat, write_in_disk=True, filename=filenames[i]) for i, true_values_i in enumerate(true_values_list)]
# Out:
# /home/antonio/dev/simple-QLL/optimization.py:30: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   exp_param.dtype = model.expparams_dtype
# /home/antonio/dev/simple-QLL/generate_experiments.py:57: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   exp_before.dtype = model.expparams_dtype
# /home/antonio/dev/simple-QLL/generate_experiments.py:60: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   exp_after.dtype = model.expparams_dtype
# Inf gain non-opt t [0.02568924].
# Inf gain after opt [0.03308667].
# Experimental time [(0.56825002,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.32772443]
# Difference squared: [[0.        0.0051572]]
# Inf gain non-opt t [0.03475381].
# Inf gain after opt [0.03291222].
# Experimental time [(0.56880649,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.31436769]
# Difference squared: [[0.         0.00341721]]
# Inf gain non-opt t [0.02494048].
# Inf gain after opt [0.03255269].
# Experimental time [(0.56923057,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.30157142]
# Difference squared: [[0.         0.00208489]]
# Inf gain non-opt t [0.07704366].
# Inf gain after opt [0.03203194].
# Experimental time [(0.56959894,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.28937589]
# Difference squared: [[0.         0.00111991]]
# Inf gain non-opt t [0.08583823].
# Inf gain after opt [0.03137137].
# Experimental time [(0.56988251,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.27780702]
# Difference squared: [[0.         0.00047944]]
# Inf gain non-opt t [0.07363231].
# Inf gain after opt [0.0358044].
# Experimental time [(0.566515,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.36246376]
# Difference squared: [[0.         0.01135353]]
# Inf gain non-opt t [0.08355669].
# Inf gain after opt [0.03631761].
# Experimental time [(0.56747982,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.34637641]
# Difference squared: [[0.         0.00818402]]
# Inf gain non-opt t [0.04362771].
# Inf gain after opt [0.03656977].
# Experimental time [(0.56834366,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.33071703]
# Difference squared: [[0.         0.00559597]]
# Inf gain non-opt t [0.05558173].
# Inf gain after opt [0.03656526].
# Experimental time [(0.569075,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.        0.3155895]
# Difference squared: [[0.         0.00356155]]
# /home/antonio/dev/simple-QLL/optimization.py:47: RuntimeWarning: divide by zero encountered in log
#   ) + 0.1*(np.exp(scalar_exp_param) - np.log(scalar_exp_param))
# Inf gain non-opt t [0.10115654].
# Inf gain after opt [0.10115654].
# Experimental time [(3.59422676,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.26824592]
# Difference squared: [[0.         0.00015215]]
# Inf gain non-opt t [0.05500718].
# Inf gain after opt [0.03251161].
# Experimental time [(0.56912432,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.30852522]
# Difference squared: [[0.         0.00276828]]
# Inf gain non-opt t [0.06202975].
# Inf gain after opt [0.03191237].
# Experimental time [(0.56951421,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.29613829]
# Difference squared: [[0.         0.00161825]]
# Inf gain non-opt t [0.06197343].
# Inf gain after opt [0.03116823].
# Experimental time [(0.56983542,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.28442297]
# Difference squared: [[0.         0.00081294]]
# Inf gain non-opt t [0.04757877].
# Inf gain after opt [0.0303084].
# Experimental time [(0.57009392,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.27338993]
# Difference squared: [[0.         0.00030552]]
# Inf gain non-opt t [0.03070094].
# Inf gain after opt [0.02936268].
# Experimental time [(0.57032156,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.26303572]
# Difference squared: [[0.00000000e+00 5.07642731e-05]]
# Inf gain non-opt t [0.06054336].
# Inf gain after opt [0.03280478].
# Experimental time [(0.56738202,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.34580438]
# Difference squared: [[0.         0.00808085]]
# Inf gain non-opt t [0.00802259].
# Inf gain after opt [0.03294066].
# Experimental time [(0.56803046,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.        0.3318868]
# Difference squared: [[0.         0.00577235]]
# Inf gain non-opt t [0.0440429].
# Inf gain after opt [0.03289109].
# Experimental time [(0.56860815,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.        0.3184247]
# Difference squared: [[0.         0.00390799]]
# Inf gain non-opt t [0.07299503].
# Inf gain after opt [0.03266829].
# Experimental time [(0.56910268,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.30547534]
# Difference squared: [[0.         0.00245664]]
# Inf gain non-opt t [0.09762153].
# Inf gain after opt [0.09762153].
# Experimental time [(4.59906563,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.26031437]
# Difference squared: [[0.00000000e+00 1.93913038e-05]]
# Inf gain non-opt t [0.02444249].
# Inf gain after opt [0.03207258].
# Experimental time [(0.56879107,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.       0.314189]
# Difference squared: [[0.         0.00339635]]
# Inf gain non-opt t [0.01072634].
# Inf gain after opt [0.03173072].
# Experimental time [(0.56919027,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.30181342]
# Difference squared: [[0.         0.00210705]]
# Inf gain non-opt t [0.01188963].
# Inf gain after opt [0.03123766].
# Experimental time [(0.56950276,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.        0.2900043]
# Difference squared: [[0.         0.00116237]]
# Inf gain non-opt t [0.09181666].
# Inf gain after opt [0.09181666].
# Experimental time [(4.51540625,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.24906501]
# Difference squared: [[0.00000000e+00 4.68650071e-05]]
# Inf gain non-opt t [0.08861649].
# Inf gain after opt [0.08861649].
# Experimental time [(3.62351605,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.39983682]
# Difference squared: [[0.        0.0207147]]
# Inf gain non-opt t [0.04110754].
# Inf gain after opt [0.03811197].
# Experimental time [(0.57007834,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.29753857]
# Difference squared: [[0.         0.00173287]]
# Inf gain non-opt t [0.03947774].
# Inf gain after opt [0.03740498].
# Experimental time [(0.57048749,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.        0.2831044]
# Difference squared: [[0.         0.00073949]]
# Inf gain non-opt t [0.00244385].
# Inf gain after opt [0.03646494].
# Experimental time [(0.57072575,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.26953779]
# Difference squared: [[0.         0.00018569]]
# Inf gain non-opt t [0.08800784].
# Inf gain after opt [0.03533889].
# Experimental time [(0.57088904,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.25685988]
# Difference squared: [[0.00000000e+00 9.00729063e-07]]
# Inf gain non-opt t [0.09515771].
# Inf gain after opt [0.03406758].
# Experimental time [(0.57093867,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.        0.2450713]
# Difference squared: [[0.         0.00011749]]
# Inf gain non-opt t [0.0970015].
# Inf gain after opt [0.03660484].
# Experimental time [(0.56900072,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.32032519]
# Difference squared: [[0.         0.00414921]]
# Inf gain non-opt t [0.00777077].
# Inf gain after opt [0.03629504].
# Experimental time [(0.56961045,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.30560906]
# Difference squared: [[0.         0.00246992]]
# Inf gain non-opt t [0.02474569].
# Inf gain after opt [0.03575654].
# Experimental time [(0.5700904,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.29161329]
# Difference squared: [[0.         0.00127467]]
# Inf gain non-opt t [0.07179947].
# Inf gain after opt [0.03502116].
# Experimental time [(0.57046458,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.27838089]
# Difference squared: [[0.        0.0005049]]
# Inf gain non-opt t [0.04767225].
# Inf gain after opt [0.03412156].
# Experimental time [(0.57071742,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.26593457]
# Difference squared: [[0.         0.00010048]]
# Inf gain non-opt t [0.07418361].
# Inf gain after opt [0.02872412].
# Experimental time [(0.5675475,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.34718172]
# Difference squared: [[0.         0.00833038]]
# Inf gain non-opt t [0.06670553].
# Inf gain after opt [0.0286793].
# Experimental time [(0.56799792,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.33522371]
# Difference squared: [[0.         0.00629054]]
# Inf gain non-opt t [0.00671797].
# Inf gain after opt [0.02850387].
# Experimental time [(0.5683966,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.32367328]
# Difference squared: [[0.         0.00459175]]
# Inf gain non-opt t [0.03041038].
# Inf gain after opt [0.02820957].
# Experimental time [(0.5687439,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.31256462]
# Difference squared: [[0.         0.00320965]]
# Inf gain non-opt t [0.0113365].
# Inf gain after opt [0.02780983].
# Experimental time [(0.56903797,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.30192218]
# Difference squared: [[0.         0.00211705]]
# Inf gain non-opt t [0.06754709].
# Inf gain after opt [0.03426801].
# Experimental time [(0.56902644,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.32265843]
# Difference squared: [[0.         0.00445524]]
# Inf gain non-opt t [0.01759314].
# Inf gain after opt [0.03376809].
# Experimental time [(0.56951591,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.30898812]
# Difference squared: [[0.        0.0028172]]
# Inf gain non-opt t [0.07724293].
# Inf gain after opt [0.0330866].
# Experimental time [(0.56992257,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.29604029]
# Difference squared: [[0.         0.00161037]]
# Inf gain non-opt t [0.0872755].
# Inf gain after opt [0.03225603].
# Experimental time [(0.57025688,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.28383759]
# Difference squared: [[0.         0.00077991]]
# Inf gain non-opt t [0.06005695].
# Inf gain after opt [0.03130898].
# Experimental time [(0.57051998,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.27238522]
# Difference squared: [[0.         0.00027141]]
# Inf gain non-opt t [0.00927629].
# Inf gain after opt [0.03256901].
# Experimental time [(0.56829612,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.33206315]
# Difference squared: [[0.         0.00579918]]
# Inf gain non-opt t [0.06867294].
# Inf gain after opt [0.03234877].
# Experimental time [(0.56881264,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.31878349]
# Difference squared: [[0.         0.00395297]]
# Inf gain non-opt t [0.04378555].
# Inf gain after opt [0.03195948].
# Experimental time [(0.56925751,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.        0.3060765]
# Difference squared: [[0.        0.0025166]]
# Inf gain non-opt t [0.05523135].
# Inf gain after opt [0.03142213].
# Experimental time [(0.56962586,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.         0.29397689]
# Difference squared: [[0.         0.00144903]]
# Inf gain non-opt t [0.03343696].
# Inf gain after opt [0.03076016].
# Experimental time [(0.569926,)]
# True parameters: [[0.         0.25591081]]
# Estimated parameters: [0.        0.2825047]
# Difference squared: [[0.         0.00070724]]

# %% [markdown]
# ## Structure:
# List with different cases.
# In each cases is a list with the different runs.
# [ [case 1 run1, case 1 run2, case 1 run3, ...],
#   [case 2 run1, case 2 run2, case 2 run3, ...],
#   ...]

# %%
case0 = joblib.load("2022-10-19_09.14_case_0.joblib")
